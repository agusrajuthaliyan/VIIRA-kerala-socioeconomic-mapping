# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("data\processed\opencellid_kerala.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140418 entries, 0 to 140417
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   radio         140418 non-null  object
#  1   mcc           140418 non-null  int64
#  2   mnc           140418 non-null  int64
#  3   lac           140418 non-null  int64
#  4   cid           140418 non-null  int64
#  5   changeable_0  140418 non-null  int64
#  6   long          140418 non-null  float64
#  7   lat           140418 non-null  float64
#  8   range         140418 non-null  int64
#  9   sample        140418 non-null  int64
#  10  changeable_1  140418 non-null  int64
#  11  created       140418 non-null  int64
#  12  updated       140418 non-null  int64
#  13  avgsignal     140418 non-null  int64
#  14  created_dt    140418 non-null  object
#  15  updated_dt    140418 non-null  object
# dtypes: float64(2), int64(11), object(3)
# memory usage: 17.1+ MB

# %%
df.describe()
# Out:
#                  mcc            mnc            lac           cid  \
# count  140418.000000  140418.000000  140418.000000  1.404180e+05
# mean      404.157238     132.484425   17121.617570  2.809336e+07
# std         0.364026     247.301453   20325.578445  5.789327e+07
# min       404.000000       3.000000       1.000000  0.000000e+00
# 25%       404.000000      19.000000     423.000000  3.068300e+04
# 50%       404.000000      46.000000    3708.000000  6.132350e+04
# 75%       404.000000      95.000000   38062.000000  2.650959e+07
# max       405.000000   14555.000000   65533.000000  2.684355e+08
#
#         changeable_0           long            lat         range  \
# count  140418.000000  140418.000000  140418.000000  1.404180e+05
# mean        1.632526      76.341840      10.169993  1.336321e+03
# std        23.373500       0.435653       0.989798  1.056513e+04
# min        -1.000000      74.871140       8.306351  5.000000e+02
# ...
